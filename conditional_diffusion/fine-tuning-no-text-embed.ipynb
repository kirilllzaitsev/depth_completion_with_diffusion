# %%
import gc
import itertools
import os
import shutil
from pathlib import Path
import matplotlib.pyplot as plt

import comet_ml
import tensorflow as tf
import torch
import torch.optim as optim
from load_data import load_data
from model import init_model
from rsl_depth_completion.conditional_diffusion.config import cfg as cfg_cls
from rsl_depth_completion.conditional_diffusion.custom_trainer import ImagenTrainer
from rsl_depth_completion.conditional_diffusion.train import train
from rsl_depth_completion.conditional_diffusion.utils import (
    dict2mdtable,
    log_params_to_exp,
)
from rsl_depth_completion.diffusion.utils import set_seed

torch.backends.cudnn.benchmark = True
# Out:
# 2023-05-26:18:03:34,449 D WARNING  [builder.py:816] Found cached dataset fashion_mnist (/media/master/wext/cv_data/hf_home/datasets/fashion_mnist/fashion_mnist/1.0.0/0a671f063342996f19779d38c0ab4abef9c64f757b35af8134b331c294d7ba48)
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
cfg = cfg_cls(path=cfg_cls.default_file)

set_seed(cfg.seed)

if cfg.is_cluster:
    if not os.path.exists(f"{cfg.tmpdir}/cluster"):
        os.system(
            f"tar -xvf /cluster/project/rsl/kzaitsev/dataset.tar -C {cfg.tmpdir}"
        )

logdir = Path("./logs") if not cfg.is_cluster else Path(cfg.cluster_logdir)
if cfg.do_overfit:
    logdir = logdir / "standalone_trainer"
else:
    logdir = logdir / "train"

# shutil.rmtree(logdir, ignore_errors=True)

best_params = {
    "kitti": {
        "use_text_embed": False,
        "use_cond_image": True,
        "use_rgb_as_cond_image": False,
    },
    "mnist": {
        "use_text_embed": True,
        "use_cond_image": False,
        "use_rgb_as_cond_image": True,
    },
}

ds_kwargs = best_params[cfg.ds_name]

ds_kwargs["use_rgb_as_text_embed"] = not ds_kwargs["use_rgb_as_cond_image"]
ds_kwargs["include_sdm_and_rgb_in_sample"] = True
ds_kwargs["do_crop"] = True
print(ds_kwargs)

ds, train_dataloader, val_dataloader = load_data(
    ds_name=cfg.ds_name, do_overfit=cfg.do_overfit, cfg=cfg, **ds_kwargs
)

experiment = comet_ml.Experiment(
    api_key="W5npcWDiWeNPoB2OYkQvwQD0C",
    project_name="rsl_depth_completion",
    auto_metric_logging=True,
    auto_param_logging=True,
    auto_histogram_tensorboard_logging=True,
    log_env_details=True,
    log_env_host=False,
    log_env_gpu=True,
    log_env_cpu=True,
    disabled=cfg.disabled,
)

experiment.log_asset("model.py", copy_to_tmp=False)
experiment.log_asset("load_data.py", copy_to_tmp=False)
experiment.log_asset("train.py", copy_to_tmp=False)
experiment.log_asset("config.py", copy_to_tmp=False)

log_params_to_exp(experiment, ds_kwargs, "dataset")
log_params_to_exp(experiment, cfg.params(), "base_config")

print(
    "Number of train samples",
    len(train_dataloader) * train_dataloader.batch_size,
)

unets, model = init_model(experiment, ds_kwargs, cfg)

num_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(
    "Number of parameters in model",
    num_params,
)

input_name = "interp_sdm"

if ds_kwargs["use_cond_image"]:
    if ds_kwargs["use_rgb_as_cond_image"]:
        img_cond = "rgb"
    else:
        img_cond = "sdm"
else:
    img_cond = "none"

if ds_kwargs["use_text_embed"]:
    if ds_kwargs["use_rgb_as_text_embed"]:
        text_cond = "rgb"
    else:
        text_cond = "sdm"
else:
    text_cond = "none"

cond = f"{img_cond=}_{text_cond=}"
exp_dir = f"{input_name=}/{cond=}/{cfg.lr=}_{cfg.timesteps=}"

exp_dir = f"{len(os.listdir(logdir)) + 1:03d}" if os.path.isdir(logdir) else "001"
train_logdir = logdir / exp_dir / cond
train_logdir.mkdir(parents=True, exist_ok=True)
# train_writer = tf.summary.create_file_writer(str(train_logdir))

trainer = ImagenTrainer(
    model,
    use_lion=False,
    lr=cfg.lr,
    max_grad_norm=1.0,
    fp16=cfg.fp16,
    use_ema=False,
    accelerate_log_with="tensorboard",
    accelerate_logging_dir="logs",
)
trainer.accelerator.init_trackers("train_example")
# Out:
# {'use_text_embed': False, 'use_cond_image': True, 'use_rgb_as_cond_image': False, 'use_rgb_as_text_embed': True, 'include_sdm_and_rgb_in_sample': True, 'do_crop': True}
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# /opt/miniconda3/envs/ssdc/lib/python3.10/site-packages/accelerate/accelerator.py:258: FutureWarning: `logging_dir` is deprecated and will be removed in version 0.18.0 of 🤗 Accelerate. Use `project_dir` instead.
#   warnings.warn(
# Number of train samples 1
# The base dimension of your u-net should ideally be no smaller than 128, as recommended by a professional DDPM trainer https://nonint.com/2022/05/04/friends-dont-let-friends-train-small-diffusion-models/
# Number of parameters in model 16231893

# %%
trainer.load('/media/master/wext/msc_studies/second_semester/research_project/project/rsl_depth_completion/rsl_depth_completion/conditional_diffusion/models/odd_atoll_8115-model-last.pt')
print(1)
# Out:
# Failed loading state dict. Trying partial load
# layer unets.0.null_text_embed(torch.Size([1, 256, 64]) different than target: torch.Size([1, 256, 32])
# layer unets.0.null_text_hidden(torch.Size([1, 256]) different than target: torch.Size([1, 128])
# layer unets.0.init_conv.convs.0.weight(torch.Size([32, 2, 3, 3]) different than target: torch.Size([16, 2, 3, 3])
# layer unets.0.init_conv.convs.0.bias(torch.Size([32]) different than target: torch.Size([16])
# layer unets.0.init_conv.convs.1.weight(torch.Size([16, 2, 7, 7]) different than target: torch.Size([8, 2, 7, 7])
# layer unets.0.init_conv.convs.1.bias(torch.Size([16]) different than target: torch.Size([8])
# layer unets.0.init_conv.convs.2.weight(torch.Size([16, 2, 15, 15]) different than target: torch.Size([8, 2, 15, 15])
# layer unets.0.init_conv.convs.2.bias(torch.Size([16]) different than target: torch.Size([8])
# layer unets.0.to_time_hiddens.1.weight(torch.Size([256, 17]) different than target: torch.Size([128, 17])
# layer unets.0.to_time_hiddens.1.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.to_time_cond.0.weight(torch.Size([256, 256]) different than target: torch.Size([128, 128])
# layer unets.0.to_time_cond.0.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.to_time_tokens.0.weight(torch.Size([128, 256]) different than target: torch.Size([64, 128])
# layer unets.0.to_time_tokens.0.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.norm_cond.weight(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.norm_cond.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.attn_pool.latents(torch.Size([32, 64]) different than target: torch.Size([32, 32])
# layer unets.0.attn_pool.pos_emb.weight(torch.Size([512, 64]) different than target: torch.Size([512, 32])
# layer unets.0.attn_pool.to_latents_from_mean_pooled_seq.0.g(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.attn_pool.to_latents_from_mean_pooled_seq.1.weight(torch.Size([256, 64]) different than target: torch.Size([128, 32])
# layer unets.0.attn_pool.to_latents_from_mean_pooled_seq.1.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.attn_pool.layers.0.0.norm.weight(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.attn_pool.layers.0.0.norm.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.attn_pool.layers.0.0.norm_latents.weight(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.attn_pool.layers.0.0.norm_latents.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.attn_pool.layers.0.0.to_q.weight(torch.Size([256, 64]) different than target: torch.Size([256, 32])
# layer unets.0.attn_pool.layers.0.0.to_kv.weight(torch.Size([512, 64]) different than target: torch.Size([512, 32])
# layer unets.0.attn_pool.layers.0.0.to_out.0.weight(torch.Size([64, 256]) different than target: torch.Size([32, 256])
# layer unets.0.attn_pool.layers.0.0.to_out.1.weight(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.attn_pool.layers.0.0.to_out.1.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.attn_pool.layers.0.1.0.g(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.attn_pool.layers.0.1.1.weight(torch.Size([256, 64]) different than target: torch.Size([128, 32])
# layer unets.0.attn_pool.layers.0.1.3.g(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.attn_pool.layers.0.1.4.weight(torch.Size([64, 256]) different than target: torch.Size([32, 128])
# layer unets.0.attn_pool.layers.1.0.norm.weight(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.attn_pool.layers.1.0.norm.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.attn_pool.layers.1.0.norm_latents.weight(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.attn_pool.layers.1.0.norm_latents.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.attn_pool.layers.1.0.to_q.weight(torch.Size([256, 64]) different than target: torch.Size([256, 32])
# layer unets.0.attn_pool.layers.1.0.to_kv.weight(torch.Size([512, 64]) different than target: torch.Size([512, 32])
# layer unets.0.attn_pool.layers.1.0.to_out.0.weight(torch.Size([64, 256]) different than target: torch.Size([32, 256])
# layer unets.0.attn_pool.layers.1.0.to_out.1.weight(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.attn_pool.layers.1.0.to_out.1.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.attn_pool.layers.1.1.0.g(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.attn_pool.layers.1.1.1.weight(torch.Size([256, 64]) different than target: torch.Size([128, 32])
# layer unets.0.attn_pool.layers.1.1.3.g(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.attn_pool.layers.1.1.4.weight(torch.Size([64, 256]) different than target: torch.Size([32, 128])
# layer unets.0.downs.0.1.time_mlp.1.weight(torch.Size([128, 256]) different than target: torch.Size([64, 128])
# layer unets.0.downs.0.1.time_mlp.1.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.0.1.block1.groupnorm.weight(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.0.1.block1.groupnorm.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.0.1.block1.project.weight(torch.Size([64, 64, 3, 3]) different than target: torch.Size([32, 32, 3, 3])
# layer unets.0.downs.0.1.block1.project.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.0.1.block2.groupnorm.weight(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.0.1.block2.groupnorm.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.0.1.block2.project.weight(torch.Size([64, 64, 3, 3]) different than target: torch.Size([32, 32, 3, 3])
# layer unets.0.downs.0.1.block2.project.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.0.2.0.time_mlp.1.weight(torch.Size([128, 256]) different than target: torch.Size([64, 128])
# layer unets.0.downs.0.2.0.time_mlp.1.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.0.2.0.block1.groupnorm.weight(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.0.2.0.block1.groupnorm.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.0.2.0.block1.project.weight(torch.Size([64, 64, 3, 3]) different than target: torch.Size([32, 32, 3, 3])
# layer unets.0.downs.0.2.0.block1.project.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.0.2.0.block2.groupnorm.weight(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.0.2.0.block2.groupnorm.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.0.2.0.block2.project.weight(torch.Size([64, 64, 3, 3]) different than target: torch.Size([32, 32, 3, 3])
# layer unets.0.downs.0.2.0.block2.project.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.0.2.0.gca.to_k.weight(torch.Size([1, 64, 1, 1]) different than target: torch.Size([1, 32, 1, 1])
# layer unets.0.downs.0.2.0.gca.net.0.weight(torch.Size([32, 64, 1, 1]) different than target: torch.Size([16, 32, 1, 1])
# layer unets.0.downs.0.2.0.gca.net.0.bias(torch.Size([32]) different than target: torch.Size([16])
# layer unets.0.downs.0.2.0.gca.net.2.weight(torch.Size([64, 32, 1, 1]) different than target: torch.Size([32, 16, 1, 1])
# layer unets.0.downs.0.2.0.gca.net.2.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.0.2.1.time_mlp.1.weight(torch.Size([128, 256]) different than target: torch.Size([64, 128])
# layer unets.0.downs.0.2.1.time_mlp.1.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.0.2.1.block1.groupnorm.weight(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.0.2.1.block1.groupnorm.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.0.2.1.block1.project.weight(torch.Size([64, 64, 3, 3]) different than target: torch.Size([32, 32, 3, 3])
# layer unets.0.downs.0.2.1.block1.project.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.0.2.1.block2.groupnorm.weight(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.0.2.1.block2.groupnorm.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.0.2.1.block2.project.weight(torch.Size([64, 64, 3, 3]) different than target: torch.Size([32, 32, 3, 3])
# layer unets.0.downs.0.2.1.block2.project.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.0.2.1.gca.to_k.weight(torch.Size([1, 64, 1, 1]) different than target: torch.Size([1, 32, 1, 1])
# layer unets.0.downs.0.2.1.gca.net.0.weight(torch.Size([32, 64, 1, 1]) different than target: torch.Size([16, 32, 1, 1])
# layer unets.0.downs.0.2.1.gca.net.0.bias(torch.Size([32]) different than target: torch.Size([16])
# layer unets.0.downs.0.2.1.gca.net.2.weight(torch.Size([64, 32, 1, 1]) different than target: torch.Size([32, 16, 1, 1])
# layer unets.0.downs.0.2.1.gca.net.2.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.0.4.1.weight(torch.Size([64, 256, 1, 1]) different than target: torch.Size([32, 128, 1, 1])
# layer unets.0.downs.0.4.1.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.1.1.time_mlp.1.weight(torch.Size([128, 256]) different than target: torch.Size([64, 128])
# layer unets.0.downs.1.1.time_mlp.1.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.1.1.block1.groupnorm.weight(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.1.1.block1.groupnorm.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.1.1.block1.project.weight(torch.Size([64, 64, 3, 3]) different than target: torch.Size([32, 32, 3, 3])
# layer unets.0.downs.1.1.block1.project.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.1.1.block2.groupnorm.weight(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.1.1.block2.groupnorm.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.1.1.block2.project.weight(torch.Size([64, 64, 3, 3]) different than target: torch.Size([32, 32, 3, 3])
# layer unets.0.downs.1.1.block2.project.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.1.2.0.time_mlp.1.weight(torch.Size([128, 256]) different than target: torch.Size([64, 128])
# layer unets.0.downs.1.2.0.time_mlp.1.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.1.2.0.block1.groupnorm.weight(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.1.2.0.block1.groupnorm.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.1.2.0.block1.project.weight(torch.Size([64, 64, 3, 3]) different than target: torch.Size([32, 32, 3, 3])
# layer unets.0.downs.1.2.0.block1.project.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.1.2.0.block2.groupnorm.weight(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.1.2.0.block2.groupnorm.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.1.2.0.block2.project.weight(torch.Size([64, 64, 3, 3]) different than target: torch.Size([32, 32, 3, 3])
# layer unets.0.downs.1.2.0.block2.project.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.1.2.0.gca.to_k.weight(torch.Size([1, 64, 1, 1]) different than target: torch.Size([1, 32, 1, 1])
# layer unets.0.downs.1.2.0.gca.net.0.weight(torch.Size([32, 64, 1, 1]) different than target: torch.Size([16, 32, 1, 1])
# layer unets.0.downs.1.2.0.gca.net.0.bias(torch.Size([32]) different than target: torch.Size([16])
# layer unets.0.downs.1.2.0.gca.net.2.weight(torch.Size([64, 32, 1, 1]) different than target: torch.Size([32, 16, 1, 1])
# layer unets.0.downs.1.2.0.gca.net.2.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.1.2.1.time_mlp.1.weight(torch.Size([128, 256]) different than target: torch.Size([64, 128])
# layer unets.0.downs.1.2.1.time_mlp.1.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.1.2.1.block1.groupnorm.weight(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.1.2.1.block1.groupnorm.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.1.2.1.block1.project.weight(torch.Size([64, 64, 3, 3]) different than target: torch.Size([32, 32, 3, 3])
# layer unets.0.downs.1.2.1.block1.project.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.1.2.1.block2.groupnorm.weight(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.1.2.1.block2.groupnorm.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.1.2.1.block2.project.weight(torch.Size([64, 64, 3, 3]) different than target: torch.Size([32, 32, 3, 3])
# layer unets.0.downs.1.2.1.block2.project.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.1.2.1.gca.to_k.weight(torch.Size([1, 64, 1, 1]) different than target: torch.Size([1, 32, 1, 1])
# layer unets.0.downs.1.2.1.gca.net.0.weight(torch.Size([32, 64, 1, 1]) different than target: torch.Size([16, 32, 1, 1])
# layer unets.0.downs.1.2.1.gca.net.0.bias(torch.Size([32]) different than target: torch.Size([16])
# layer unets.0.downs.1.2.1.gca.net.2.weight(torch.Size([64, 32, 1, 1]) different than target: torch.Size([32, 16, 1, 1])
# layer unets.0.downs.1.2.1.gca.net.2.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.1.4.1.weight(torch.Size([64, 256, 1, 1]) different than target: torch.Size([32, 128, 1, 1])
# layer unets.0.downs.1.4.1.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.2.1.time_mlp.1.weight(torch.Size([128, 256]) different than target: torch.Size([64, 128])
# layer unets.0.downs.2.1.time_mlp.1.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.2.1.block1.groupnorm.weight(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.2.1.block1.groupnorm.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.2.1.block1.project.weight(torch.Size([64, 64, 3, 3]) different than target: torch.Size([32, 32, 3, 3])
# layer unets.0.downs.2.1.block1.project.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.2.1.block2.groupnorm.weight(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.2.1.block2.groupnorm.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.2.1.block2.project.weight(torch.Size([64, 64, 3, 3]) different than target: torch.Size([32, 32, 3, 3])
# layer unets.0.downs.2.1.block2.project.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.2.2.0.time_mlp.1.weight(torch.Size([128, 256]) different than target: torch.Size([64, 128])
# layer unets.0.downs.2.2.0.time_mlp.1.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.2.2.0.block1.groupnorm.weight(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.2.2.0.block1.groupnorm.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.2.2.0.block1.project.weight(torch.Size([64, 64, 3, 3]) different than target: torch.Size([32, 32, 3, 3])
# layer unets.0.downs.2.2.0.block1.project.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.2.2.0.block2.groupnorm.weight(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.2.2.0.block2.groupnorm.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.2.2.0.block2.project.weight(torch.Size([64, 64, 3, 3]) different than target: torch.Size([32, 32, 3, 3])
# layer unets.0.downs.2.2.0.block2.project.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.2.2.0.gca.to_k.weight(torch.Size([1, 64, 1, 1]) different than target: torch.Size([1, 32, 1, 1])
# layer unets.0.downs.2.2.0.gca.net.0.weight(torch.Size([32, 64, 1, 1]) different than target: torch.Size([16, 32, 1, 1])
# layer unets.0.downs.2.2.0.gca.net.0.bias(torch.Size([32]) different than target: torch.Size([16])
# layer unets.0.downs.2.2.0.gca.net.2.weight(torch.Size([64, 32, 1, 1]) different than target: torch.Size([32, 16, 1, 1])
# layer unets.0.downs.2.2.0.gca.net.2.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.2.2.1.time_mlp.1.weight(torch.Size([128, 256]) different than target: torch.Size([64, 128])
# layer unets.0.downs.2.2.1.time_mlp.1.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.2.2.1.block1.groupnorm.weight(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.2.2.1.block1.groupnorm.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.2.2.1.block1.project.weight(torch.Size([64, 64, 3, 3]) different than target: torch.Size([32, 32, 3, 3])
# layer unets.0.downs.2.2.1.block1.project.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.2.2.1.block2.groupnorm.weight(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.2.2.1.block2.groupnorm.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.2.2.1.block2.project.weight(torch.Size([64, 64, 3, 3]) different than target: torch.Size([32, 32, 3, 3])
# layer unets.0.downs.2.2.1.block2.project.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.2.2.1.gca.to_k.weight(torch.Size([1, 64, 1, 1]) different than target: torch.Size([1, 32, 1, 1])
# layer unets.0.downs.2.2.1.gca.net.0.weight(torch.Size([32, 64, 1, 1]) different than target: torch.Size([16, 32, 1, 1])
# layer unets.0.downs.2.2.1.gca.net.0.bias(torch.Size([32]) different than target: torch.Size([16])
# layer unets.0.downs.2.2.1.gca.net.2.weight(torch.Size([64, 32, 1, 1]) different than target: torch.Size([32, 16, 1, 1])
# layer unets.0.downs.2.2.1.gca.net.2.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.2.4.1.weight(torch.Size([128, 256, 1, 1]) different than target: torch.Size([64, 128, 1, 1])
# layer unets.0.downs.2.4.1.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.3.1.time_mlp.1.weight(torch.Size([256, 256]) different than target: torch.Size([128, 128])
# layer unets.0.downs.3.1.time_mlp.1.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.downs.3.1.block1.groupnorm.weight(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.3.1.block1.groupnorm.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.3.1.block1.project.weight(torch.Size([128, 128, 3, 3]) different than target: torch.Size([64, 64, 3, 3])
# layer unets.0.downs.3.1.block1.project.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.3.1.block2.groupnorm.weight(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.3.1.block2.groupnorm.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.3.1.block2.project.weight(torch.Size([128, 128, 3, 3]) different than target: torch.Size([64, 64, 3, 3])
# layer unets.0.downs.3.1.block2.project.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.3.2.0.time_mlp.1.weight(torch.Size([256, 256]) different than target: torch.Size([128, 128])
# layer unets.0.downs.3.2.0.time_mlp.1.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.downs.3.2.0.block1.groupnorm.weight(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.3.2.0.block1.groupnorm.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.3.2.0.block1.project.weight(torch.Size([128, 128, 3, 3]) different than target: torch.Size([64, 64, 3, 3])
# layer unets.0.downs.3.2.0.block1.project.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.3.2.0.block2.groupnorm.weight(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.3.2.0.block2.groupnorm.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.3.2.0.block2.project.weight(torch.Size([128, 128, 3, 3]) different than target: torch.Size([64, 64, 3, 3])
# layer unets.0.downs.3.2.0.block2.project.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.3.2.0.gca.to_k.weight(torch.Size([1, 128, 1, 1]) different than target: torch.Size([1, 64, 1, 1])
# layer unets.0.downs.3.2.0.gca.net.0.weight(torch.Size([64, 128, 1, 1]) different than target: torch.Size([32, 64, 1, 1])
# layer unets.0.downs.3.2.0.gca.net.0.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.3.2.0.gca.net.2.weight(torch.Size([128, 64, 1, 1]) different than target: torch.Size([64, 32, 1, 1])
# layer unets.0.downs.3.2.0.gca.net.2.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.3.2.1.time_mlp.1.weight(torch.Size([256, 256]) different than target: torch.Size([128, 128])
# layer unets.0.downs.3.2.1.time_mlp.1.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.downs.3.2.1.block1.groupnorm.weight(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.3.2.1.block1.groupnorm.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.3.2.1.block1.project.weight(torch.Size([128, 128, 3, 3]) different than target: torch.Size([64, 64, 3, 3])
# layer unets.0.downs.3.2.1.block1.project.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.3.2.1.block2.groupnorm.weight(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.3.2.1.block2.groupnorm.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.3.2.1.block2.project.weight(torch.Size([128, 128, 3, 3]) different than target: torch.Size([64, 64, 3, 3])
# layer unets.0.downs.3.2.1.block2.project.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.3.2.1.gca.to_k.weight(torch.Size([1, 128, 1, 1]) different than target: torch.Size([1, 64, 1, 1])
# layer unets.0.downs.3.2.1.gca.net.0.weight(torch.Size([64, 128, 1, 1]) different than target: torch.Size([32, 64, 1, 1])
# layer unets.0.downs.3.2.1.gca.net.0.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.3.2.1.gca.net.2.weight(torch.Size([128, 64, 1, 1]) different than target: torch.Size([64, 32, 1, 1])
# layer unets.0.downs.3.2.1.gca.net.2.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.3.4.1.weight(torch.Size([128, 512, 1, 1]) different than target: torch.Size([64, 256, 1, 1])
# layer unets.0.downs.3.4.1.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.4.1.time_mlp.1.weight(torch.Size([256, 256]) different than target: torch.Size([128, 128])
# layer unets.0.downs.4.1.time_mlp.1.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.downs.4.1.block1.groupnorm.weight(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.4.1.block1.groupnorm.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.4.1.block1.project.weight(torch.Size([128, 128, 3, 3]) different than target: torch.Size([64, 64, 3, 3])
# layer unets.0.downs.4.1.block1.project.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.4.1.block2.groupnorm.weight(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.4.1.block2.groupnorm.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.4.1.block2.project.weight(torch.Size([128, 128, 3, 3]) different than target: torch.Size([64, 64, 3, 3])
# layer unets.0.downs.4.1.block2.project.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.4.2.0.time_mlp.1.weight(torch.Size([256, 256]) different than target: torch.Size([128, 128])
# layer unets.0.downs.4.2.0.time_mlp.1.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.downs.4.2.0.block1.groupnorm.weight(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.4.2.0.block1.groupnorm.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.4.2.0.block1.project.weight(torch.Size([128, 128, 3, 3]) different than target: torch.Size([64, 64, 3, 3])
# layer unets.0.downs.4.2.0.block1.project.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.4.2.0.block2.groupnorm.weight(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.4.2.0.block2.groupnorm.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.4.2.0.block2.project.weight(torch.Size([128, 128, 3, 3]) different than target: torch.Size([64, 64, 3, 3])
# layer unets.0.downs.4.2.0.block2.project.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.4.2.0.gca.to_k.weight(torch.Size([1, 128, 1, 1]) different than target: torch.Size([1, 64, 1, 1])
# layer unets.0.downs.4.2.0.gca.net.0.weight(torch.Size([64, 128, 1, 1]) different than target: torch.Size([32, 64, 1, 1])
# layer unets.0.downs.4.2.0.gca.net.0.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.4.2.0.gca.net.2.weight(torch.Size([128, 64, 1, 1]) different than target: torch.Size([64, 32, 1, 1])
# layer unets.0.downs.4.2.0.gca.net.2.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.4.2.1.time_mlp.1.weight(torch.Size([256, 256]) different than target: torch.Size([128, 128])
# layer unets.0.downs.4.2.1.time_mlp.1.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.downs.4.2.1.block1.groupnorm.weight(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.4.2.1.block1.groupnorm.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.4.2.1.block1.project.weight(torch.Size([128, 128, 3, 3]) different than target: torch.Size([64, 64, 3, 3])
# layer unets.0.downs.4.2.1.block1.project.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.4.2.1.block2.groupnorm.weight(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.4.2.1.block2.groupnorm.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.4.2.1.block2.project.weight(torch.Size([128, 128, 3, 3]) different than target: torch.Size([64, 64, 3, 3])
# layer unets.0.downs.4.2.1.block2.project.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.4.2.1.gca.to_k.weight(torch.Size([1, 128, 1, 1]) different than target: torch.Size([1, 64, 1, 1])
# layer unets.0.downs.4.2.1.gca.net.0.weight(torch.Size([64, 128, 1, 1]) different than target: torch.Size([32, 64, 1, 1])
# layer unets.0.downs.4.2.1.gca.net.0.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.4.2.1.gca.net.2.weight(torch.Size([128, 64, 1, 1]) different than target: torch.Size([64, 32, 1, 1])
# layer unets.0.downs.4.2.1.gca.net.2.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.4.4.1.weight(torch.Size([256, 512, 1, 1]) different than target: torch.Size([128, 256, 1, 1])
# layer unets.0.downs.4.4.1.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.downs.5.1.time_mlp.1.weight(torch.Size([512, 256]) different than target: torch.Size([256, 128])
# layer unets.0.downs.5.1.time_mlp.1.bias(torch.Size([512]) different than target: torch.Size([256])
# layer unets.0.downs.5.1.cross_attn.norm.g(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.downs.5.1.cross_attn.to_q.weight(torch.Size([256, 256]) different than target: torch.Size([256, 128])
# layer unets.0.downs.5.1.cross_attn.to_kv.weight(torch.Size([512, 64]) different than target: torch.Size([512, 32])
# layer unets.0.downs.5.1.cross_attn.to_out.0.weight(torch.Size([256, 256]) different than target: torch.Size([128, 256])
# layer unets.0.downs.5.1.cross_attn.to_out.1.g(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.downs.5.1.block1.groupnorm.weight(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.downs.5.1.block1.groupnorm.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.downs.5.1.block1.project.weight(torch.Size([256, 256, 3, 3]) different than target: torch.Size([128, 128, 3, 3])
# layer unets.0.downs.5.1.block1.project.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.downs.5.1.block2.groupnorm.weight(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.downs.5.1.block2.groupnorm.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.downs.5.1.block2.project.weight(torch.Size([256, 256, 3, 3]) different than target: torch.Size([128, 128, 3, 3])
# layer unets.0.downs.5.1.block2.project.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.downs.5.2.0.time_mlp.1.weight(torch.Size([512, 256]) different than target: torch.Size([256, 128])
# layer unets.0.downs.5.2.0.time_mlp.1.bias(torch.Size([512]) different than target: torch.Size([256])
# layer unets.0.downs.5.2.0.block1.groupnorm.weight(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.downs.5.2.0.block1.groupnorm.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.downs.5.2.0.block1.project.weight(torch.Size([256, 256, 3, 3]) different than target: torch.Size([128, 128, 3, 3])
# layer unets.0.downs.5.2.0.block1.project.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.downs.5.2.0.block2.groupnorm.weight(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.downs.5.2.0.block2.groupnorm.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.downs.5.2.0.block2.project.weight(torch.Size([256, 256, 3, 3]) different than target: torch.Size([128, 128, 3, 3])
# layer unets.0.downs.5.2.0.block2.project.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.downs.5.2.0.gca.to_k.weight(torch.Size([1, 256, 1, 1]) different than target: torch.Size([1, 128, 1, 1])
# layer unets.0.downs.5.2.0.gca.net.0.weight(torch.Size([128, 256, 1, 1]) different than target: torch.Size([64, 128, 1, 1])
# layer unets.0.downs.5.2.0.gca.net.0.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.5.2.0.gca.net.2.weight(torch.Size([256, 128, 1, 1]) different than target: torch.Size([128, 64, 1, 1])
# layer unets.0.downs.5.2.0.gca.net.2.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.downs.5.2.1.time_mlp.1.weight(torch.Size([512, 256]) different than target: torch.Size([256, 128])
# layer unets.0.downs.5.2.1.time_mlp.1.bias(torch.Size([512]) different than target: torch.Size([256])
# layer unets.0.downs.5.2.1.block1.groupnorm.weight(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.downs.5.2.1.block1.groupnorm.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.downs.5.2.1.block1.project.weight(torch.Size([256, 256, 3, 3]) different than target: torch.Size([128, 128, 3, 3])
# layer unets.0.downs.5.2.1.block1.project.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.downs.5.2.1.block2.groupnorm.weight(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.downs.5.2.1.block2.groupnorm.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.downs.5.2.1.block2.project.weight(torch.Size([256, 256, 3, 3]) different than target: torch.Size([128, 128, 3, 3])
# layer unets.0.downs.5.2.1.block2.project.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.downs.5.2.1.gca.to_k.weight(torch.Size([1, 256, 1, 1]) different than target: torch.Size([1, 128, 1, 1])
# layer unets.0.downs.5.2.1.gca.net.0.weight(torch.Size([128, 256, 1, 1]) different than target: torch.Size([64, 128, 1, 1])
# layer unets.0.downs.5.2.1.gca.net.0.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.downs.5.2.1.gca.net.2.weight(torch.Size([256, 128, 1, 1]) different than target: torch.Size([128, 64, 1, 1])
# layer unets.0.downs.5.2.1.gca.net.2.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.downs.5.3.layers.0.0.norm.g(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.downs.5.3.layers.0.0.to_q.weight(torch.Size([256, 256]) different than target: torch.Size([256, 128])
# layer unets.0.downs.5.3.layers.0.0.to_kv.weight(torch.Size([128, 256]) different than target: torch.Size([128, 128])
# layer unets.0.downs.5.3.layers.0.0.to_context.0.weight(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.5.3.layers.0.0.to_context.0.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.downs.5.3.layers.0.0.to_context.1.weight(torch.Size([128, 64]) different than target: torch.Size([128, 32])
# layer unets.0.downs.5.3.layers.0.0.to_out.0.weight(torch.Size([256, 256]) different than target: torch.Size([128, 256])
# layer unets.0.downs.5.3.layers.0.0.to_out.1.g(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.downs.5.3.layers.0.1.0.g(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.downs.5.3.layers.0.1.1.weight(torch.Size([512, 256]) different than target: torch.Size([256, 128])
# layer unets.0.downs.5.3.layers.0.1.3.g(torch.Size([512]) different than target: torch.Size([256])
# layer unets.0.downs.5.3.layers.0.1.4.weight(torch.Size([256, 512]) different than target: torch.Size([128, 256])
# layer unets.0.downs.5.4.fns.0.weight(torch.Size([256, 256, 3, 3]) different than target: torch.Size([128, 128, 3, 3])
# layer unets.0.downs.5.4.fns.0.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.downs.5.4.fns.1.weight(torch.Size([256, 256, 1, 1]) different than target: torch.Size([128, 128, 1, 1])
# layer unets.0.downs.5.4.fns.1.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.0.0.time_mlp.1.weight(torch.Size([512, 256]) different than target: torch.Size([256, 128])
# layer unets.0.ups.0.0.time_mlp.1.bias(torch.Size([512]) different than target: torch.Size([256])
# layer unets.0.ups.0.0.cross_attn.norm.g(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.0.0.cross_attn.to_q.weight(torch.Size([256, 256]) different than target: torch.Size([256, 128])
# layer unets.0.ups.0.0.cross_attn.to_kv.weight(torch.Size([512, 64]) different than target: torch.Size([512, 32])
# layer unets.0.ups.0.0.cross_attn.to_out.0.weight(torch.Size([256, 256]) different than target: torch.Size([128, 256])
# layer unets.0.ups.0.0.cross_attn.to_out.1.g(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.0.0.block1.groupnorm.weight(torch.Size([512]) different than target: torch.Size([256])
# layer unets.0.ups.0.0.block1.groupnorm.bias(torch.Size([512]) different than target: torch.Size([256])
# layer unets.0.ups.0.0.block1.project.weight(torch.Size([256, 512, 3, 3]) different than target: torch.Size([128, 256, 3, 3])
# layer unets.0.ups.0.0.block1.project.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.0.0.block2.groupnorm.weight(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.0.0.block2.groupnorm.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.0.0.block2.project.weight(torch.Size([256, 256, 3, 3]) different than target: torch.Size([128, 128, 3, 3])
# layer unets.0.ups.0.0.block2.project.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.0.0.res_conv.weight(torch.Size([256, 512, 1, 1]) different than target: torch.Size([128, 256, 1, 1])
# layer unets.0.ups.0.0.res_conv.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.0.1.0.time_mlp.1.weight(torch.Size([512, 256]) different than target: torch.Size([256, 128])
# layer unets.0.ups.0.1.0.time_mlp.1.bias(torch.Size([512]) different than target: torch.Size([256])
# layer unets.0.ups.0.1.0.block1.groupnorm.weight(torch.Size([512]) different than target: torch.Size([256])
# layer unets.0.ups.0.1.0.block1.groupnorm.bias(torch.Size([512]) different than target: torch.Size([256])
# layer unets.0.ups.0.1.0.block1.project.weight(torch.Size([256, 512, 3, 3]) different than target: torch.Size([128, 256, 3, 3])
# layer unets.0.ups.0.1.0.block1.project.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.0.1.0.block2.groupnorm.weight(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.0.1.0.block2.groupnorm.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.0.1.0.block2.project.weight(torch.Size([256, 256, 3, 3]) different than target: torch.Size([128, 128, 3, 3])
# layer unets.0.ups.0.1.0.block2.project.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.0.1.0.gca.to_k.weight(torch.Size([1, 256, 1, 1]) different than target: torch.Size([1, 128, 1, 1])
# layer unets.0.ups.0.1.0.gca.net.0.weight(torch.Size([128, 256, 1, 1]) different than target: torch.Size([64, 128, 1, 1])
# layer unets.0.ups.0.1.0.gca.net.0.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.ups.0.1.0.gca.net.2.weight(torch.Size([256, 128, 1, 1]) different than target: torch.Size([128, 64, 1, 1])
# layer unets.0.ups.0.1.0.gca.net.2.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.0.1.0.res_conv.weight(torch.Size([256, 512, 1, 1]) different than target: torch.Size([128, 256, 1, 1])
# layer unets.0.ups.0.1.0.res_conv.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.0.1.1.time_mlp.1.weight(torch.Size([512, 256]) different than target: torch.Size([256, 128])
# layer unets.0.ups.0.1.1.time_mlp.1.bias(torch.Size([512]) different than target: torch.Size([256])
# layer unets.0.ups.0.1.1.block1.groupnorm.weight(torch.Size([512]) different than target: torch.Size([256])
# layer unets.0.ups.0.1.1.block1.groupnorm.bias(torch.Size([512]) different than target: torch.Size([256])
# layer unets.0.ups.0.1.1.block1.project.weight(torch.Size([256, 512, 3, 3]) different than target: torch.Size([128, 256, 3, 3])
# layer unets.0.ups.0.1.1.block1.project.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.0.1.1.block2.groupnorm.weight(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.0.1.1.block2.groupnorm.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.0.1.1.block2.project.weight(torch.Size([256, 256, 3, 3]) different than target: torch.Size([128, 128, 3, 3])
# layer unets.0.ups.0.1.1.block2.project.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.0.1.1.gca.to_k.weight(torch.Size([1, 256, 1, 1]) different than target: torch.Size([1, 128, 1, 1])
# layer unets.0.ups.0.1.1.gca.net.0.weight(torch.Size([128, 256, 1, 1]) different than target: torch.Size([64, 128, 1, 1])
# layer unets.0.ups.0.1.1.gca.net.0.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.ups.0.1.1.gca.net.2.weight(torch.Size([256, 128, 1, 1]) different than target: torch.Size([128, 64, 1, 1])
# layer unets.0.ups.0.1.1.gca.net.2.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.0.1.1.res_conv.weight(torch.Size([256, 512, 1, 1]) different than target: torch.Size([128, 256, 1, 1])
# layer unets.0.ups.0.1.1.res_conv.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.0.2.layers.0.0.norm.g(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.0.2.layers.0.0.to_q.weight(torch.Size([256, 256]) different than target: torch.Size([256, 128])
# layer unets.0.ups.0.2.layers.0.0.to_kv.weight(torch.Size([128, 256]) different than target: torch.Size([128, 128])
# layer unets.0.ups.0.2.layers.0.0.to_context.0.weight(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.ups.0.2.layers.0.0.to_context.0.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.ups.0.2.layers.0.0.to_context.1.weight(torch.Size([128, 64]) different than target: torch.Size([128, 32])
# layer unets.0.ups.0.2.layers.0.0.to_out.0.weight(torch.Size([256, 256]) different than target: torch.Size([128, 256])
# layer unets.0.ups.0.2.layers.0.0.to_out.1.g(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.0.2.layers.0.1.0.g(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.0.2.layers.0.1.1.weight(torch.Size([512, 256]) different than target: torch.Size([256, 128])
# layer unets.0.ups.0.2.layers.0.1.3.g(torch.Size([512]) different than target: torch.Size([256])
# layer unets.0.ups.0.2.layers.0.1.4.weight(torch.Size([256, 512]) different than target: torch.Size([128, 256])
# layer unets.0.ups.0.3.net.0.weight(torch.Size([1024, 256, 1, 1]) different than target: torch.Size([512, 128, 1, 1])
# layer unets.0.ups.0.3.net.0.bias(torch.Size([1024]) different than target: torch.Size([512])
# layer unets.0.ups.1.0.time_mlp.1.weight(torch.Size([512, 256]) different than target: torch.Size([256, 128])
# layer unets.0.ups.1.0.time_mlp.1.bias(torch.Size([512]) different than target: torch.Size([256])
# layer unets.0.ups.1.0.block1.groupnorm.weight(torch.Size([384]) different than target: torch.Size([192])
# layer unets.0.ups.1.0.block1.groupnorm.bias(torch.Size([384]) different than target: torch.Size([192])
# layer unets.0.ups.1.0.block1.project.weight(torch.Size([256, 384, 3, 3]) different than target: torch.Size([128, 192, 3, 3])
# layer unets.0.ups.1.0.block1.project.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.1.0.block2.groupnorm.weight(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.1.0.block2.groupnorm.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.1.0.block2.project.weight(torch.Size([256, 256, 3, 3]) different than target: torch.Size([128, 128, 3, 3])
# layer unets.0.ups.1.0.block2.project.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.1.0.res_conv.weight(torch.Size([256, 384, 1, 1]) different than target: torch.Size([128, 192, 1, 1])
# layer unets.0.ups.1.0.res_conv.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.1.1.0.time_mlp.1.weight(torch.Size([512, 256]) different than target: torch.Size([256, 128])
# layer unets.0.ups.1.1.0.time_mlp.1.bias(torch.Size([512]) different than target: torch.Size([256])
# layer unets.0.ups.1.1.0.block1.groupnorm.weight(torch.Size([384]) different than target: torch.Size([192])
# layer unets.0.ups.1.1.0.block1.groupnorm.bias(torch.Size([384]) different than target: torch.Size([192])
# layer unets.0.ups.1.1.0.block1.project.weight(torch.Size([256, 384, 3, 3]) different than target: torch.Size([128, 192, 3, 3])
# layer unets.0.ups.1.1.0.block1.project.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.1.1.0.block2.groupnorm.weight(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.1.1.0.block2.groupnorm.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.1.1.0.block2.project.weight(torch.Size([256, 256, 3, 3]) different than target: torch.Size([128, 128, 3, 3])
# layer unets.0.ups.1.1.0.block2.project.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.1.1.0.gca.to_k.weight(torch.Size([1, 256, 1, 1]) different than target: torch.Size([1, 128, 1, 1])
# layer unets.0.ups.1.1.0.gca.net.0.weight(torch.Size([128, 256, 1, 1]) different than target: torch.Size([64, 128, 1, 1])
# layer unets.0.ups.1.1.0.gca.net.0.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.ups.1.1.0.gca.net.2.weight(torch.Size([256, 128, 1, 1]) different than target: torch.Size([128, 64, 1, 1])
# layer unets.0.ups.1.1.0.gca.net.2.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.1.1.0.res_conv.weight(torch.Size([256, 384, 1, 1]) different than target: torch.Size([128, 192, 1, 1])
# layer unets.0.ups.1.1.0.res_conv.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.1.1.1.time_mlp.1.weight(torch.Size([512, 256]) different than target: torch.Size([256, 128])
# layer unets.0.ups.1.1.1.time_mlp.1.bias(torch.Size([512]) different than target: torch.Size([256])
# layer unets.0.ups.1.1.1.block1.groupnorm.weight(torch.Size([384]) different than target: torch.Size([192])
# layer unets.0.ups.1.1.1.block1.groupnorm.bias(torch.Size([384]) different than target: torch.Size([192])
# layer unets.0.ups.1.1.1.block1.project.weight(torch.Size([256, 384, 3, 3]) different than target: torch.Size([128, 192, 3, 3])
# layer unets.0.ups.1.1.1.block1.project.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.1.1.1.block2.groupnorm.weight(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.1.1.1.block2.groupnorm.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.1.1.1.block2.project.weight(torch.Size([256, 256, 3, 3]) different than target: torch.Size([128, 128, 3, 3])
# layer unets.0.ups.1.1.1.block2.project.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.1.1.1.gca.to_k.weight(torch.Size([1, 256, 1, 1]) different than target: torch.Size([1, 128, 1, 1])
# layer unets.0.ups.1.1.1.gca.net.0.weight(torch.Size([128, 256, 1, 1]) different than target: torch.Size([64, 128, 1, 1])
# layer unets.0.ups.1.1.1.gca.net.0.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.ups.1.1.1.gca.net.2.weight(torch.Size([256, 128, 1, 1]) different than target: torch.Size([128, 64, 1, 1])
# layer unets.0.ups.1.1.1.gca.net.2.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.1.1.1.res_conv.weight(torch.Size([256, 384, 1, 1]) different than target: torch.Size([128, 192, 1, 1])
# layer unets.0.ups.1.1.1.res_conv.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.1.3.net.0.weight(torch.Size([512, 256, 1, 1]) different than target: torch.Size([256, 128, 1, 1])
# layer unets.0.ups.1.3.net.0.bias(torch.Size([512]) different than target: torch.Size([256])
# layer unets.0.ups.2.0.time_mlp.1.weight(torch.Size([256, 256]) different than target: torch.Size([128, 128])
# layer unets.0.ups.2.0.time_mlp.1.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.2.0.block1.groupnorm.weight(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.2.0.block1.groupnorm.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.2.0.block1.project.weight(torch.Size([128, 256, 3, 3]) different than target: torch.Size([64, 128, 3, 3])
# layer unets.0.ups.2.0.block1.project.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.ups.2.0.block2.groupnorm.weight(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.ups.2.0.block2.groupnorm.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.ups.2.0.block2.project.weight(torch.Size([128, 128, 3, 3]) different than target: torch.Size([64, 64, 3, 3])
# ...
# layer unets.0.ups.4.0.time_mlp.1.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.ups.4.0.block1.groupnorm.weight(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.ups.4.0.block1.groupnorm.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.ups.4.0.block1.project.weight(torch.Size([64, 128, 3, 3]) different than target: torch.Size([32, 64, 3, 3])
# layer unets.0.ups.4.0.block1.project.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.ups.4.0.block2.groupnorm.weight(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.ups.4.0.block2.groupnorm.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.ups.4.0.block2.project.weight(torch.Size([64, 64, 3, 3]) different than target: torch.Size([32, 32, 3, 3])
# layer unets.0.ups.4.0.block2.project.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.ups.4.0.res_conv.weight(torch.Size([64, 128, 1, 1]) different than target: torch.Size([32, 64, 1, 1])
# layer unets.0.ups.4.0.res_conv.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.ups.4.1.0.time_mlp.1.weight(torch.Size([128, 256]) different than target: torch.Size([64, 128])
# layer unets.0.ups.4.1.0.time_mlp.1.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.ups.4.1.0.block1.groupnorm.weight(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.ups.4.1.0.block1.groupnorm.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.ups.4.1.0.block1.project.weight(torch.Size([64, 128, 3, 3]) different than target: torch.Size([32, 64, 3, 3])
# layer unets.0.ups.4.1.0.block1.project.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.ups.4.1.0.block2.groupnorm.weight(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.ups.4.1.0.block2.groupnorm.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.ups.4.1.0.block2.project.weight(torch.Size([64, 64, 3, 3]) different than target: torch.Size([32, 32, 3, 3])
# layer unets.0.ups.4.1.0.block2.project.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.ups.4.1.0.gca.to_k.weight(torch.Size([1, 64, 1, 1]) different than target: torch.Size([1, 32, 1, 1])
# layer unets.0.ups.4.1.0.gca.net.0.weight(torch.Size([32, 64, 1, 1]) different than target: torch.Size([16, 32, 1, 1])
# layer unets.0.ups.4.1.0.gca.net.0.bias(torch.Size([32]) different than target: torch.Size([16])
# layer unets.0.ups.4.1.0.gca.net.2.weight(torch.Size([64, 32, 1, 1]) different than target: torch.Size([32, 16, 1, 1])
# layer unets.0.ups.4.1.0.gca.net.2.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.ups.4.1.0.res_conv.weight(torch.Size([64, 128, 1, 1]) different than target: torch.Size([32, 64, 1, 1])
# layer unets.0.ups.4.1.0.res_conv.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.ups.4.1.1.time_mlp.1.weight(torch.Size([128, 256]) different than target: torch.Size([64, 128])
# layer unets.0.ups.4.1.1.time_mlp.1.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.ups.4.1.1.block1.groupnorm.weight(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.ups.4.1.1.block1.groupnorm.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.ups.4.1.1.block1.project.weight(torch.Size([64, 128, 3, 3]) different than target: torch.Size([32, 64, 3, 3])
# layer unets.0.ups.4.1.1.block1.project.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.ups.4.1.1.block2.groupnorm.weight(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.ups.4.1.1.block2.groupnorm.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.ups.4.1.1.block2.project.weight(torch.Size([64, 64, 3, 3]) different than target: torch.Size([32, 32, 3, 3])
# layer unets.0.ups.4.1.1.block2.project.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.ups.4.1.1.gca.to_k.weight(torch.Size([1, 64, 1, 1]) different than target: torch.Size([1, 32, 1, 1])
# layer unets.0.ups.4.1.1.gca.net.0.weight(torch.Size([32, 64, 1, 1]) different than target: torch.Size([16, 32, 1, 1])
# layer unets.0.ups.4.1.1.gca.net.0.bias(torch.Size([32]) different than target: torch.Size([16])
# layer unets.0.ups.4.1.1.gca.net.2.weight(torch.Size([64, 32, 1, 1]) different than target: torch.Size([32, 16, 1, 1])
# layer unets.0.ups.4.1.1.gca.net.2.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.ups.4.1.1.res_conv.weight(torch.Size([64, 128, 1, 1]) different than target: torch.Size([32, 64, 1, 1])
# layer unets.0.ups.4.1.1.res_conv.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.ups.4.3.net.0.weight(torch.Size([256, 64, 1, 1]) different than target: torch.Size([128, 32, 1, 1])
# layer unets.0.ups.4.3.net.0.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.ups.5.0.time_mlp.1.weight(torch.Size([128, 256]) different than target: torch.Size([64, 128])
# layer unets.0.ups.5.0.time_mlp.1.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.ups.5.0.block1.groupnorm.weight(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.ups.5.0.block1.groupnorm.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.ups.5.0.block1.project.weight(torch.Size([64, 128, 3, 3]) different than target: torch.Size([32, 64, 3, 3])
# layer unets.0.ups.5.0.block1.project.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.ups.5.0.block2.groupnorm.weight(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.ups.5.0.block2.groupnorm.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.ups.5.0.block2.project.weight(torch.Size([64, 64, 3, 3]) different than target: torch.Size([32, 32, 3, 3])
# layer unets.0.ups.5.0.block2.project.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.ups.5.0.res_conv.weight(torch.Size([64, 128, 1, 1]) different than target: torch.Size([32, 64, 1, 1])
# layer unets.0.ups.5.0.res_conv.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.ups.5.1.0.time_mlp.1.weight(torch.Size([128, 256]) different than target: torch.Size([64, 128])
# layer unets.0.ups.5.1.0.time_mlp.1.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.ups.5.1.0.block1.groupnorm.weight(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.ups.5.1.0.block1.groupnorm.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.ups.5.1.0.block1.project.weight(torch.Size([64, 128, 3, 3]) different than target: torch.Size([32, 64, 3, 3])
# layer unets.0.ups.5.1.0.block1.project.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.ups.5.1.0.block2.groupnorm.weight(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.ups.5.1.0.block2.groupnorm.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.ups.5.1.0.block2.project.weight(torch.Size([64, 64, 3, 3]) different than target: torch.Size([32, 32, 3, 3])
# layer unets.0.ups.5.1.0.block2.project.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.ups.5.1.0.gca.to_k.weight(torch.Size([1, 64, 1, 1]) different than target: torch.Size([1, 32, 1, 1])
# layer unets.0.ups.5.1.0.gca.net.0.weight(torch.Size([32, 64, 1, 1]) different than target: torch.Size([16, 32, 1, 1])
# layer unets.0.ups.5.1.0.gca.net.0.bias(torch.Size([32]) different than target: torch.Size([16])
# layer unets.0.ups.5.1.0.gca.net.2.weight(torch.Size([64, 32, 1, 1]) different than target: torch.Size([32, 16, 1, 1])
# layer unets.0.ups.5.1.0.gca.net.2.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.ups.5.1.0.res_conv.weight(torch.Size([64, 128, 1, 1]) different than target: torch.Size([32, 64, 1, 1])
# layer unets.0.ups.5.1.0.res_conv.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.ups.5.1.1.time_mlp.1.weight(torch.Size([128, 256]) different than target: torch.Size([64, 128])
# layer unets.0.ups.5.1.1.time_mlp.1.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.ups.5.1.1.block1.groupnorm.weight(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.ups.5.1.1.block1.groupnorm.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.ups.5.1.1.block1.project.weight(torch.Size([64, 128, 3, 3]) different than target: torch.Size([32, 64, 3, 3])
# layer unets.0.ups.5.1.1.block1.project.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.ups.5.1.1.block2.groupnorm.weight(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.ups.5.1.1.block2.groupnorm.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.ups.5.1.1.block2.project.weight(torch.Size([64, 64, 3, 3]) different than target: torch.Size([32, 32, 3, 3])
# layer unets.0.ups.5.1.1.block2.project.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.ups.5.1.1.gca.to_k.weight(torch.Size([1, 64, 1, 1]) different than target: torch.Size([1, 32, 1, 1])
# layer unets.0.ups.5.1.1.gca.net.0.weight(torch.Size([32, 64, 1, 1]) different than target: torch.Size([16, 32, 1, 1])
# layer unets.0.ups.5.1.1.gca.net.0.bias(torch.Size([32]) different than target: torch.Size([16])
# layer unets.0.ups.5.1.1.gca.net.2.weight(torch.Size([64, 32, 1, 1]) different than target: torch.Size([32, 16, 1, 1])
# layer unets.0.ups.5.1.1.gca.net.2.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.ups.5.1.1.res_conv.weight(torch.Size([64, 128, 1, 1]) different than target: torch.Size([32, 64, 1, 1])
# layer unets.0.ups.5.1.1.res_conv.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.mid_block1.time_mlp.1.weight(torch.Size([512, 256]) different than target: torch.Size([256, 128])
# layer unets.0.mid_block1.time_mlp.1.bias(torch.Size([512]) different than target: torch.Size([256])
# layer unets.0.mid_block1.cross_attn.norm.g(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.mid_block1.cross_attn.to_q.weight(torch.Size([512, 256]) different than target: torch.Size([512, 128])
# layer unets.0.mid_block1.cross_attn.to_kv.weight(torch.Size([1024, 64]) different than target: torch.Size([1024, 32])
# layer unets.0.mid_block1.cross_attn.to_out.0.weight(torch.Size([256, 512]) different than target: torch.Size([128, 512])
# layer unets.0.mid_block1.cross_attn.to_out.1.g(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.mid_block1.block1.groupnorm.weight(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.mid_block1.block1.groupnorm.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.mid_block1.block1.project.weight(torch.Size([256, 256, 3, 3]) different than target: torch.Size([128, 128, 3, 3])
# layer unets.0.mid_block1.block1.project.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.mid_block1.block2.groupnorm.weight(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.mid_block1.block2.groupnorm.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.mid_block1.block2.project.weight(torch.Size([256, 256, 3, 3]) different than target: torch.Size([128, 128, 3, 3])
# layer unets.0.mid_block1.block2.project.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.mid_block2.time_mlp.1.weight(torch.Size([512, 256]) different than target: torch.Size([256, 128])
# layer unets.0.mid_block2.time_mlp.1.bias(torch.Size([512]) different than target: torch.Size([256])
# layer unets.0.mid_block2.cross_attn.norm.g(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.mid_block2.cross_attn.to_q.weight(torch.Size([512, 256]) different than target: torch.Size([512, 128])
# layer unets.0.mid_block2.cross_attn.to_kv.weight(torch.Size([1024, 64]) different than target: torch.Size([1024, 32])
# layer unets.0.mid_block2.cross_attn.to_out.0.weight(torch.Size([256, 512]) different than target: torch.Size([128, 512])
# layer unets.0.mid_block2.cross_attn.to_out.1.g(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.mid_block2.block1.groupnorm.weight(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.mid_block2.block1.groupnorm.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.mid_block2.block1.project.weight(torch.Size([256, 256, 3, 3]) different than target: torch.Size([128, 128, 3, 3])
# layer unets.0.mid_block2.block1.project.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.mid_block2.block2.groupnorm.weight(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.mid_block2.block2.groupnorm.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.mid_block2.block2.project.weight(torch.Size([256, 256, 3, 3]) different than target: torch.Size([128, 128, 3, 3])
# layer unets.0.mid_block2.block2.project.bias(torch.Size([256]) different than target: torch.Size([128])
# layer unets.0.final_res_block.time_mlp.1.weight(torch.Size([128, 256]) different than target: torch.Size([64, 128])
# layer unets.0.final_res_block.time_mlp.1.bias(torch.Size([128]) different than target: torch.Size([64])
# layer unets.0.final_res_block.block1.groupnorm.weight(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.final_res_block.block1.groupnorm.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.final_res_block.block1.project.weight(torch.Size([64, 64, 3, 3]) different than target: torch.Size([32, 32, 3, 3])
# layer unets.0.final_res_block.block1.project.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.final_res_block.block2.groupnorm.weight(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.final_res_block.block2.groupnorm.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.final_res_block.block2.project.weight(torch.Size([64, 64, 3, 3]) different than target: torch.Size([32, 32, 3, 3])
# layer unets.0.final_res_block.block2.project.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.final_res_block.gca.to_k.weight(torch.Size([1, 64, 1, 1]) different than target: torch.Size([1, 32, 1, 1])
# layer unets.0.final_res_block.gca.net.0.weight(torch.Size([32, 64, 1, 1]) different than target: torch.Size([16, 32, 1, 1])
# layer unets.0.final_res_block.gca.net.0.bias(torch.Size([32]) different than target: torch.Size([16])
# layer unets.0.final_res_block.gca.net.2.weight(torch.Size([64, 32, 1, 1]) different than target: torch.Size([32, 16, 1, 1])
# layer unets.0.final_res_block.gca.net.2.bias(torch.Size([64]) different than target: torch.Size([32])
# layer unets.0.final_conv.weight(torch.Size([1, 64, 3, 3]) different than target: torch.Size([1, 32, 3, 3])
# could not load optimizer and scaler, possibly because you have turned on mixed precision training since the last run. resuming with new optimizer and scalers
# could not load optimizer and scaler, possibly because you have turned on mixed precision training since the last run. resuming with new optimizer and scalers
# checkpoint loaded from /media/master/wext/msc_studies/second_semester/research_project/project/rsl_depth_completion/rsl_depth_completion/conditional_diffusion/models/odd_atoll_8115-model-last.pt
# 1
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
eval_batch = ds.eval_batch

# %%
eval_batch = ds.eval_batch
if cfg.do_sample:
    eval_text_embeds = (
        eval_batch["text_embed"]
        if "text_embed" in eval_batch
        else None
    )
    eval_cond_images = (
        eval_batch["cond_image"]
        if "cond_image" in eval_batch
        else None
    )

    samples = trainer.sample(
        text_embeds=eval_text_embeds,
        cond_images=eval_cond_images,
        cond_scale=cfg.cond_scale,
        batch_size=cfg.batch_size,
        stop_at_unet_number=None,
        return_all_unet_outputs=True,
    )
# Out:
# 0it [00:00, ?it/s]
# sampling loop time step:   0%|          | 0/200 [00:00<?, ?it/s]

# %%
def compare_diff_cond_scales(trainer):
    cond_scales = list(range(0, 14, 2))
    fix, axs = plt.subplots(1, len(cond_scales), figsize=(20, 5))
    for i, cond_scale in enumerate(cond_scales):
        samples = trainer.sample(
            text_embeds=eval_text_embeds,
            cond_images=eval_cond_images,
            cond_scale=cond_scale,
            batch_size=cfg.batch_size,
            stop_at_unet_number=None,
            return_all_unet_outputs=True,
        )
        axs[i].imshow(samples[0][0].permute(1, 2, 0).cpu().numpy())
        axs[i].set_title(f"cond_scale={cond_scale}")
        if i!=0:
            axs[i].set_yticklabels([])
            axs[i].set_yticks([])
            axs[i].set_xticklabels([])
            axs[i].set_xticks([])
    plt.show()
